# %%
# %matplotlib inline
import h5pyd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from random import randint

# %%
# %%time
# Open the GEOSFP "file"
f = h5pyd.File("/home/hdf/harvardseas/GEOSFP/GEOSFP.20150701.A3cld.Native.nc", "r")
# Out:
# CPU times: user 4 ms, sys: 4 ms, total: 8 ms
# Wall time: 299 ms

# %%
# %%time
list(f)
# Out:
# CPU times: user 8 ms, sys: 0 ns, total: 8 ms
# Wall time: 202 ms
# [u'CLOUD',
#  u'OPTDEPTH',
#  u'QCCU',
#  u'QI',
#  u'QL',
#  u'TAUCLI',
#  u'TAUCLW',
#  u'lat',
#  u'lev',
#  u'lon',
#  u'time']

# %%
# %%time
cloud = f["CLOUD"]
# Out:
# CPU times: user 4 ms, sys: 0 ns, total: 4 ms
# Wall time: 102 ms

# %%
cloud.id.id
# Out:
# u'd-1762b7fa-b48b-11e7-a042-0242ac11000a'

# %%
cloud.shape
# Out:
# (8, 72, 721, 1152)

# %%
cloud.dtype
# Out:
# dtype('float32')

# %%
# %%time
cloud.attrs["gamap_category"]
# Out:
# CPU times: user 8 ms, sys: 0 ns, total: 8 ms
# Wall time: 101 ms
# 'GMAO-3D$'

# %%
# %%time
# first index possible range 0-7
# second index possible range 0-71
data = cloud[3, 24, ::2, ::2] # select over other value in last two dimensions
# Out:
# CPU times: user 8 ms, sys: 8 ms, total: 16 ms
# Wall time: 734 ms

# %%
data.min()
# Out:
# 0.0

# %%
data.max()
# Out:
# 0.91979247

# %%
# %%time
plt.imshow(data)
# Out:
# CPU times: user 36 ms, sys: 8 ms, total: 44 ms
# Wall time: 38.9 ms
